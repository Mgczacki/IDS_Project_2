# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../movieReplicationSet.csv')

# %%
df
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# 4                         3.5           NaN
# ...                       ...           ...
# 1092                      NaN           NaN
# 1093                      NaN           NaN
# 1094                      NaN           NaN
# 1095                      NaN           NaN
# 1096                      4.0           NaN
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                           3.0            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           3.0            NaN
# 4                                           0.5            NaN
# ...                                         ...            ...
# 1092                                        3.5            NaN
# 1093                                        4.0            4.0
# 1094                                        NaN            NaN
# 1095                                        NaN            NaN
# 1096                                        2.5            NaN
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                   NaN           NaN
# 4                                   0.5           1.0
# ...                                 ...           ...
# 1092                                NaN           NaN
# 1093                                2.5           NaN
# 1094                                NaN           3.5
# 1095                                NaN           NaN
# 1096                                NaN           3.0
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  \
# 0                             NaN                NaN  ...
# 1                             NaN                NaN  ...
# 2                             NaN                NaN  ...
# 3                             NaN                4.0  ...
# 4                             NaN                0.0  ...
# ...                           ...                ...  ...
# 1092                          NaN                NaN  ...
# 1093                          3.5                3.5  ...
# 1094                          NaN                NaN  ...
# 1095                          NaN                NaN  ...
# 1096                          NaN                3.5  ...
#
#       When watching a movie I cheer or shout or talk or curse at the screen  \
# 0                                                   1.0
# 1                                                   3.0
# 2                                                   5.0
# 3                                                   3.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                1.0
# 1096                                                3.0
#
#       When watching a movie I feel like the things on the screen are happening to me  \
# 0                                                   6.0
# 1                                                   1.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   3.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                3.0
# 1094                                                3.0
# 1095                                                1.0
# 1096                                                4.0
#
#       As a movie unfolds I start to have problems keeping track of events that happened earlier  \
# 0                                                   2.0
# 1                                                   1.0
# 2                                                   3.0
# 3                                                   1.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared  \
# 0                                                   5.0
# 1                                                   6.0
# 2                                                   5.0
# 3                                                   4.0
# 4                                                   5.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                4.0
# 1096                                                4.0
#
#       When watching a movie I get completely immersed in the alternative reality of the film  \
# 0                                                   5.0
# 1                                                   5.0
# 2                                                   5.0
# 3                                                   5.0
# 4                                                   6.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                3.0
# 1096                                                4.0
#
#       Movies change my position on social economic or political issues  \
# 0                                                   5.0
# 1                                                   3.0
# 2                                                   4.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                6.0
# 1094                                                4.0
# 1095                                                3.0
# 1096                                                4.0
#
#       When watching movies things get so intense that I have to stop watching  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                5.0
# 1094                                                2.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Gender identity (1 = female; 2 = male; 3 = self-described)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 1092                                                1.0
# 1093                                                1.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Are you an only child? (1: Yes; 0: No; -1: Did not respond)  \
# 0                                                     0
# 1                                                     0
# 2                                                     1
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  0
# 1096                                                  0
#
#       Movies are best enjoyed alone (1: Yes; 0: No; -1: Did not respond)
# 0                                                     1
# 1                                                     0
# 2                                                     0
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  1
# 1096                                                  1
#
# [1097 rows x 477 columns]

# %%
movie_cols = df.columns[0:400]

# %%
movie_cols
# Out:
# Index(['The Life of David Gale (2003)', 'Wing Commander (1999)',
#        'Django Unchained (2012)', 'Alien (1979)',
#        'Indiana Jones and the Last Crusade (1989)', 'Snatch (2000)',
#        'Rambo: First Blood Part II (1985)', 'Fargo (1996)',
#        'Let the Right One In (2008)', 'Black Swan (2010)',
#        ...
#        'X-Men 2 (2003)', 'The Usual Suspects (1995)', 'The Mask (1994)',
#        'Jaws (1975)', 'Harry Potter and the Chamber of Secrets (2002)',
#        'Patton (1970)', 'Anaconda (1997)', 'Twister (1996)',
#        'MacArthur (1977)', 'Look Who's Talking (1989)'],
#       dtype='object', length=400)

# %%
sensation_cols = df.columns[400:420]

# %%
sensation_cols
# Out:
# Index(['I enjoy driving fast', 'I enjoy rollercoasters ',
#        'Have you ever bungee-jumped?', 'I enjoy impulse shopping',
#        'I sometimes go out on weeknights even if I have work to do',
#        'I enjoy doing things without too much planning ',
#        'Have you ever been rock climbing?',
#        'I enjoy being in large loud crowds like the Times Square Ball Drop on New Years Eve',
#        'I enjoy going to large music or dance festivals ',
#        'I enjoy watching horror movies', 'No risk - No fun',
#        'I like to be surprised even if it startles or scares me',
#        'Have you ever parachuted?', 'I enjoy haunted houses',
#        'I had a sheltered upbringing', 'My life is very stressful',
#        'I value my life to be well ordered and predictable',
#        'Have you ridden a motorcycle?', 'Have you gambled or bet for money?',
#        'Have you ever been sky-diving?'],
#       dtype='object')

# %%
personality_cols = df.columns[420:464]

# %%
personality_cols
# Out:
# Index(['Is talkative', 'Tends to find fault with others',
#        'Does a thorough job', 'Is depressed/Blue',
#        'Is original/comes up with new ideas', 'Is reserved',
#        'Is helpful and unselfish with others', 'Can be somewhat careless',
#        'Is relaxed/handles stress well',
#        'Is curious about many different things', 'Is full of energy',
#        'Starts quarrels with others', 'Is a reliable worker', 'Can be tense',
#        'Is ingenious/a deep thinker', 'Generates a lot of Enthusiasm',
#        'Has a forgiving nature', 'Tends to be disorganized', 'Worries a lot',
#        'Has an active imagination', 'Tends to be quiet',
#        'Is generally trusting', 'Tends to be lazy',
#        'Is emotionally stable/not easily upset', 'is inventive',
#        'Has an assertive personality', 'Can be cold and aloof',
#        'Perseveres until the task is finished', 'Can be moody',
#        'Values artistic/aesthetic experiences', 'Is sometimes shy/inhibited',
#        'Is considerate and kind to almost everyone', 'Does things efficiently',
#        'Remains calm in tense situations', 'Prefers work that is routine',
#        'is outgoing/sociable', 'Is sometimes rude to others',
#        'Makes plans and follows through with them', 'Gets nervous easily',
#        'Likes to reflect/play with ideas', 'Has few artistic interests',
#        'Likes to cooperate with others', 'Is easily distracted',
#        'Is sophisticated in art or music or literature'],
#       dtype='object')

# %%
movie_rating_cols = df.columns[464:474]

# %%
movie_rating_cols
# Out:
# Index(['I have cried during a movie',
#        'I have trouble following the story of a movie',
#        'I have trouble remembering the story of a movie a couple of days after seeing it',
#        'When watching a movie I cheer or shout or talk or curse at the screen',
#        'When watching a movie I feel like the things on the screen are happening to me',
#        'As a movie unfolds I start to have problems keeping track of events that happened earlier',
#        'The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared',
#        'When watching a movie I get completely immersed in the alternative reality of the film',
#        'Movies change my position on social economic or political issues',
#        'When watching movies things get so intense that I have to stop watching'],
#       dtype='object')

# %%
gender_identity_cols = df.columns[474:475]

# %%
gender_identity_cols
# Out:
# Index(['Gender identity (1 = female; 2 = male; 3 = self-described)'], dtype='object')

# %%
only_child_cols = df.columns[475:476]

# %%
only_child_cols
# Out:
# Index(['Are you an only child? (1: Yes; 0: No; -1: Did not respond)'], dtype='object')

# %%
alone_cols = df.columns[476:477]

# %%
alone_cols
# Out:
# Index(['Movies are best enjoyed alone (1: Yes; 0: No; -1: Did not respond)'], dtype='object')

# %% [markdown]
# All movies have at least one rating, but this is not the case for all users. Dropping completely empty users.

# %%
df_movies = df[movie_cols]
df_movies = df_movies.dropna(how='all', subset=movie_cols)

# %%
avg_movie = df_movies.mean(axis = 0)
avg_usr = df_movies.mean(axis = 1)

# %%
def fill_na(x):
    movie_avg_val = avg_movie[x.name]
    fill_vals = (avg_usr + movie_avg_val)/2
    return x.fillna(fill_vals)

# %%
df_filled = df_movies.apply(fill_na)

# %% [markdown]
# # AFYD
#
# 1. **D**: What did you do - what assumptions/choices did you make, if any (e.g. re
# independence, type of data, etc.)?
# 2. **Y**: Why did you do this - what was the reasoning for doing this (over all other possible things you could have done)?
# 3. **F**: What did you find doing that - at least one number (e.g. a p-value or an effect size), better a number *and* a figure. Context is better – what does the number represent, how was it arrived at (what was the test statistic and degrees of freedom?)
# 4. **A**: Given all of that, how do you answer the question, sth like "Given that my p value is x, I conclude that y]. If you made any questionable assumptions above, this is also where you might want to state limitations to the scope of your answer, if there are any, and you are aware of them. It's fine to have limitations, if you spell them out (e.g. concerns about alpha inflation, independence, distribution of data, etc - if there are any).

# %% [markdown]
# ### General assumptions for the work:

# %% [markdown]
# - The movie ratings can be treated as continuous variables.
# - The missing movie ratings can be filled as the arithmetic mean between a user's average rating and a movie's average rating. We are careful not to include the answers of the other questions in this fill.
# - For other questions that are not movie ratings, missing questions will be filled with the mode.

# %% [markdown]
# # Question 1:
#
# For each of the 400 movies, use a simple linear regression model to predict the ratings. Use the ratings
# of the *other* 399 movies in the dataset to predict the ratings of each movie (that means you’ll have
# to build 399 models for each of the 400 movies). For each of the 400 movies, find the movie that
# predicts ratings the best. Then report the average COD of those 400 simple linear regression models.
# Please include a histogram of these 400 COD values and a table with the 10 movies that are most
# easily predicted from the ratings of a single other movie and the 10 movies that are hardest to predict
# from the ratings of a single other movie (and their associated COD values, as well as which movie
# ratings are the best predictor, so this table should have 3 columns).

# %%
from sklearn.linear_model import LinearRegression

# %%
movie_cod = dict()
movie_score = dict()
movie_best_predictor = dict()

for movie in df_filled.columns:
    other_movies = [other_movie for other_movie in df_movies.columns if other_movie != movie]
    best_predictor = None
    best_cod = None
    best_score = np.infty
    for predictor_movie in other_movies:
        X = df_filled[[predictor_movie]].values
        y = df_movies[movie].values.reshape(-1)
        valid_mask = ~np.isnan(y)
        X = X[valid_mask]
        y = y[valid_mask]
        reg = LinearRegression().fit(X, y)
        preds = reg.predict(X)
        score = np.sum((y-preds)**2)
        if score < best_score:
            best_predictor = predictor_movie
            best_cod = reg.score(X, y)
            best_score = score
    movie_cod[movie] = best_cod
    movie_score[movie] = best_score
    movie_best_predictor[movie] = best_predictor

# %% [markdown]
# For each of the 400 movies, find the movie that predicts ratings the best.

# %%
movie_best_predictor
# Out:
# {'The Life of David Gale (2003)': 'Flowers in the Attic (1987)',
#  'Wing Commander (1999)': 'Funny Girl (1968)',
#  'Django Unchained (2012)': 'Inglorious Bastards (2009)',
#  'Alien (1979)': 'Aliens (1986)',
#  'Indiana Jones and the Last Crusade (1989)': 'Indiana Jones and the Temple of Doom (1984)',
#  'Snatch (2000)': 'Full Metal Jacket (1987)',
#  'Rambo: First Blood Part II (1985)': 'Godzilla (1998)',
#  'Fargo (1996)': 'Taxi Driver (1976)',
#  'Let the Right One In (2008)': 'Brazil (1985)',
#  'Black Swan (2010)': 'The Shining (1980)',
#  'King Kong (1976)': 'Indiana Jones and the Temple of Doom (1984)',
#  'The Machinist (2004)': 'Requiem for a Dream (2000)',
#  'A Nightmare on Elm Street (1984)': 'The Exorcist (1973)',
#  'Brazil (1985)': 'The Bridges of Madison County (1995)',
#  'The Fast and the Furious (2001)': 'Transformers: Age of Extinction (2014)',
#  'Change of Habit (1969)': 'Just Like Heaven (2005)',
#  'American Beauty (1999)': 'The Shining (1980)',
#  'Psycho (1960)': 'The Shining (1980)',
#  'Terminator 3: Rise of the Machines (2003)': 'Terminator 2: Judgement Day (1991)',
#  'Night of the Living Dead (1968)': 'The Texas Chainsaw Massacre (1974)',
#  'Man on Fire (2004)': 'Cool Hand Luke (1967)',
#  'Star Wars: Episode IV - A New Hope (1977)': 'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'The Silence of the Lambs (1991)': 'The Exorcist (1973)',
#  'The Others (2001)': 'Barbarella (1968)',
#  'Minority Report (2002)': 'From Hell (2001)',
#  'Sling Blade (1996)': 'The Bridges of Madison County (1995)',
#  "Schindler's List (1993)": 'Leon (1994)',
#  '3000 Miles to Graceland (2001)': 'Just Like Heaven (2005)',
#  'Magnolia (1999)': 'Brazil (1985)',
#  'The Karate Kid Part II (1986)': 'Chain Reaction (1996)',
#  'Planet of the Apes (2001)': 'Jurassic Park III (2001)',
#  'The Godfather: Part II (1974)': 'The Godfather (1972)',
#  'Indiana Jones and the Temple of Doom (1984)': 'Indiana Jones and the Last Crusade (1989)',
#  'Indiana Jones and the Raiders of the Lost Ark (1981)': 'Indiana Jones and the Last Crusade (1989)',
#  'The Iron Giant (1999)': 'JFK (1991)',
#  'The Matrix Revolutions (2003)': 'The Matrix Reloaded (2003)',
#  'North (1994)': 'Chain Reaction (1996)',
#  'The Lost World: Jurassic Park (1997)': 'Jurassic Park III (2001)',
#  'The Texas Chainsaw Massacre (1974)': 'A Nightmare on Elm Street (1984)',
#  'Taxi Driver (1976)': 'Diamonds are Forever (1971)',
#  'Back to the Future (1985)': '3000 Miles to Graceland (2001)',
#  '13 Going on 30 (2004)': 'Cheaper by the Dozen (2003)',
#  'Sorority Boys (2002)': 'Pieces of April (2003)',
#  'The Bridges of Madison County (1995)': 'Brazil (1985)',
#  'Billy Madison (1995)': 'Happy Gilmore (1996)',
#  'Chain Reaction (1996)': 'North (1994)',
#  'Batman & Robin (1997)': 'Iron Man 3 (2013)',
#  'Jurassic Park III (2001)': 'The Lost World: Jurassic Park (1997)',
#  'Platoon (1986)': 'Diamonds are Forever (1971)',
#  'Signs (2002)': 'Barb Wire (1996)',
#  'Terms of Endearment (1983)': 'Boomerang (1992)',
#  'Mission: Impossible II (2000)': 'Men in Black II (2002)',
#  'Lost in Translation (2003)': 'Cool Hand Luke (1967)',
#  'Star Trek: The Motion Picture (1979)': 'Star Wars: Episode IV - A New Hope (1977)',
#  'Inglorious Bastards (2009)': 'Django Unchained (2012)',
#  'Clueless (1995)': 'Back to the Future (1985)',
#  'The Omen (1976)': 'The Exorcist (1973)',
#  'Shrek 2 (2004)': 'Shrek (2001)',
#  'Good Will Hunting (1997)': 'Brazil (1985)',
#  'Just Like Heaven (2005)': '3000 Miles to Graceland (2001)',
#  'Showgirls (1995)': 'Cool Hand Luke (1967)',
#  'Diamonds are Forever (1971)': 'Taxi Driver (1976)',
#  'Crossroads (2002)': 'Taxi Driver (1976)',
#  'Pieces of April (2003)': 'Crossroads (2002)',
#  'Torque (2004)': 'A Beautiful Mind (2001)',
#  'Poltergeist (1982)': 'The Texas Chainsaw Massacre (1974)',
#  'Fear and Loathing in Las Vegas (1998)': 'Lost in Translation (2003)',
#  'Barbarella (1968)': 'The King of Marvin Gardens (1972)',
#  'The King of Marvin Gardens (1972)': 'Barbarella (1968)',
#  'The Poseidon Adventure (1972)': 'Terms of Endearment (1983)',
#  'The Rock (1996)': 'Platoon (1986)',
#  'Love Story (1970)': 'A Beautiful Mind (2001)',
#  'The Last Samurai (2003)': 'FeardotCom (2002)',
#  'The Jungle Book (1967)': 'Tarzan (1999)',
#  'The Exorcist (1973)': 'The Conjuring (2013)',
#  "Pirates of the Caribbean: Dead Man's Chest (2006)": "Pirates of the Caribbean: At World's End (2007)",
#  'Gone in Sixty Seconds (2000)': 'The Bridges of Madison County (1995)',
#  'Funny Girl (1968)': 'Fear and Loathing in Las Vegas (1998)',
#  'Honey (2003)': 'Billy Jack (1971)',
#  'Blues Brothers 2000 (1998)': 'Andaz Apna Apna (1994)',
#  'Avatar (2009)': "Pirates of the Caribbean: Dead Man's Chest (2006)",
#  'The Pianist (2002)': 'Cool Hand Luke (1967)',
#  'Godzilla (1998)': 'The Lost World: Jurassic Park (1997)',
#  'Fight Club (1999)': 'Pulp Fiction (1994)',
#  'The Conjuring (2013)': 'The Exorcist (1973)',
#  'Top Gun (1986)': 'Diamonds are Forever (1971)',
#  'Slackers (2002)': 'Cool Hand Luke (1967)',
#  'Shrek (2001)': 'Shrek 2 (2004)',
#  '12 Monkeys (1995)': 'Change of Habit (1969)',
#  'From Hell (2001)': 'Brazil (1985)',
#  'Dead Poets Society (1989)': 'Good Will Hunting (1997)',
#  'Once Upon a Time in America (1984)': 'Man on Fire (2004)',
#  'Equilibrium (2002)': 'Sling Blade (1996)',
#  'Star Wars: Episode II - Attack of the Clones (2002)': 'Star Wars: Episode 1 - The Phantom Menace (1999)',
#  'The Thing (1982)': 'Alien (1979)',
#  'Interstellar (2014)': 'Torque (2004)',
#  'Full Metal Jacket (1987)': 'Magnolia (1999)',
#  'Big Fish (2003)': 'Chain Reaction (1996)',
#  'Cool Hand Luke (1967)': 'Man on Fire (2004)',
#  'A Beautiful Mind (2001)': 'Life is Beautiful (1997)',
#  'Sholay (1978)': 'The Deer Hunter (1978)',
#  'The 51st State (2001)': 'A Time to Kill (1996)',
#  'Die Hard With a Vengeance (1995)': 'Uptown Girls (2003)',
#  'Elf (2003)': 'Cheaper by the Dozen (2003)',
#  'The Blue Lagoon (1980)': 'Batman (1989)',
#  'Hellraiser (1987)': "Rosemary's Baby (1968)",
#  'Moonraker (1979)': 'Unforgiven (1992)',
#  'Leon (1994)': 'Requiem for a Dream (2000)',
#  'Mystic River (2003)': 'Escape from LA (1996)',
#  'Sexy Beast (2000)': 'Scent of a Woman (1992)',
#  'Beetle Juice (1988)': 'The Nightmare Before Christmas (1993)',
#  'Andaz Apna Apna (1994)': 'Chicago (2002)',
#  'The Proposal (2009)': 'Cheaper by the Dozen (2003)',
#  'The Shining (1980)': 'Psycho (1960)',
#  'The Land That Time Forgot (1974)': 'JFK (1991)',
#  'The Perfect Storm (2000)': 'Stir Crazy (1980)',
#  'Escape from LA (1996)': 'Runaway Bride (1999)',
#  'Shutter Island (2010)': 'The Shawshank Redemption (1994)',
#  'JFK (1991)': 'Unforgiven (1992)',
#  'Barb Wire (1996)': 'The Firm (1993)',
#  'Oldboy (2003)': 'Andaz Apna Apna (1994)',
#  'Carrie (1976)': 'The Exorcist (1973)',
#  'The Good the Bad and the Ugly (1966)': 'Being John Malkovich (1999)',
#  'Speed 2: Cruise Control (1997)': 'The Lookout (2007)',
#  'The Lord of the Rings: The Fellowship of the Ring (2001)': 'The Lord of the Rings: The Two Towers (2002)',
#  'The Talented Mr. Ripley (1999)': 'Die Another Day (2002)',
#  'Casino (1995)': 'Gangs of New York (2002)',
#  'A Time to Kill (1996)': 'Date and Switch (2014)',
#  'Blazing Saddles (1974)': 'Carrie (1976)',
#  'The Doom Generation (1995)': 'Andaz Apna Apna (1994)',
#  'Armageddon (1998)': 'JFK (1991)',
#  'X-Men (2000)': 'X-Men 2 (2003)',
#  'Arachnophobia (1990)': 'Halloween (1978)',
#  'Stir Crazy (1980)': 'The Silencers (1966)',
#  'Billy Jack (1971)': 'Sexy Beast (2000)',
#  'The Silencers (1966)': 'Stir Crazy (1980)',
#  'The Three Musketeers (1993)': 'The 51st State (2001)',
#  'Girl Interrupted (1999)': 'Gangs of New York (2002)',
#  'Finding Nemo (2003)': 'Monsters  Inc.(2001)',
#  'Tropic of Cancer (1970)': 'Once Upon a Time in the West (1968)',
#  'The Sixth Sense (1999)': 'The Deer Hunter (1978)',
#  'I Know What You Did Last Summer (1997)': 'Scream (1996)',
#  'Indiana Jones and the Kingdom of the Crystal Skull (2008)': "Pirates of the Caribbean: At World's End (2007)",
#  'Divine Secrets of the Ya-Ya Sisterhood (2002)': 'Stir Crazy (1980)',
#  'Ace Ventura: When Nature Calls (1995)': 'Mrs. Doubtfire (1993)',
#  'Dances with Wolves (1990)': 'Almost Famous (2000)',
#  'Date and Switch (2014)': "Who's Afraid of Virginia Woolf (1966)",
#  'The Intouchables (2011)': 'Adaption (2002)',
#  'Mrs. Doubtfire (1993)': 'American History X (1998)',
#  'Ghostbusters (2016)': 'Divine Secrets of the Ya-Ya Sisterhood (2002)',
#  'Almost Famous (2000)': 'Scent of a Woman (1992)',
#  'Blade Runner (1982)': 'Fargo (1996)',
#  'Unforgiven (1992)': 'Moonraker (1979)',
#  "Rosemary's Baby (1968)": 'Hellraiser (1987)',
#  'Cheaper by the Dozen (2003)': 'Escape from LA (1996)',
#  "Can't Hardly Wait (1998)": 'Divine Secrets of the Ya-Ya Sisterhood (2002)',
#  'Die Another Day (2002)': 'Escape from LA (1996)',
#  'Toy Story 2 (1999)': 'Toy Story 3 (2010)',
#  'Transformers: Age of Extinction (2014)': 'Iron Man 3 (2013)',
#  'Like Stars on Earth (2007)': "Father's Day (1997)",
#  'Terminator 2: Judgement Day (1991)': 'Terminator 3: Rise of the Machines (2003)',
#  '25th Hour (2002)': 'Almost Famous (2000)',
#  "Who's Afraid of Virginia Woolf (1966)": 'Date and Switch (2014)',
#  'Adaption (2002)': 'Scent of a Woman (1992)',
#  'Life is Beautiful (1997)': 'A Beautiful Mind (2001)',
#  'Room (2015)': 'The Shawshank Redemption (1994)',
#  'Scream (1996)': 'Scream 3 (2000)',
#  'The Evil Dead (1981)': 'Halloween (1978)',
#  'Gangs of New York (2002)': 'Casino (1995)',
#  'Stand By Me (1986)': 'Almost Famous (2000)',
#  'The Vow (2012)': 'The Proposal (2009)',
#  'Toy Story 3 (2010)': 'Toy Story 2 (1999)',
#  'The Matrix Reloaded (2003)': 'The Matrix Revolutions (2003)',
#  'Once Upon a Time in the West (1968)': 'FeardotCom (2002)',
#  'Star Wars: Episode V - The Empire Strikes Back (1980)': 'Star Wars: Episode IV - A New Hope (1977)',
#  'War Games (1983)': '25th Hour (2002)',
#  'Kill Bill: Vol. 2 (2004)': 'Kill Bill: Vol. 1 (2003)',
#  'Saving Private Ryan (1998)': "One Flew Over the Cuckoo's Nest (1975)",
#  'Just Married (2003)': 'The Insider (1999)',
#  'Being John Malkovich (1999)': 'Escape from LA (1996)',
#  "Father's Day (1997)": 'Platoon (1986)',
#  'Batman (1989)': 'The Blue Lagoon (1980)',
#  'Se7en (1995)': 'Escape from LA (1996)',
#  'Happy Gilmore (1996)': 'Billy Madison (1995)',
#  'My Big Fat Greek Wedding (2002)': "Father's Day (1997)",
#  'Boomerang (1992)': 'A Time to Kill (1996)',
#  'The Avengers (2012)': 'Captain America: Civil War (2016)',
#  'In America (2002)': 'Stir Crazy (1980)',
#  'Tarzan (1999)': 'Aladdin (1992)',
#  'Scent of a Woman (1992)': 'Almost Famous (2000)',
#  'The Cabin in the Woods (2012)': 'The Texas Chainsaw Massacre (1974)',
#  'Spider-Man (2002)': 'Batman (1989)',
#  'Broken Arrow (1996)': 'Star Wars: Episode 1 - The Phantom Menace (1999)',
#  'Baby Geniuses (1999)': "There's Something About Mary (1998)",
#  'Battlefield Earth (2000)': 'Escape from LA (1996)',
#  'The Firm (1993)': 'Uptown Girls (2003)',
#  'De-Lovely (2004)': 'The Firm (1993)',
#  'Die Hard (1988)': 'Escape from LA (1996)',
#  'The Lord of the Rings: The Two Towers (2002)': 'The Lord of the Rings: The Fellowship of the Ring (2001)',
#  'The Blair Witch Project (1999)': 'Carrie (1976)',
#  'Judge Dredd (1995)': 'Moonraker (1979)',
#  '10 Things I Hate About You (1999)': 'The Insider (1999)',
#  'The Insider (1999)': 'Hollow Man (2000)',
#  'Erik the Viking (1989)': 'I.Q. (1994)',
#  "Pirates of the Caribbean: At World's End (2007)": "Pirates of the Caribbean: Dead Man's Chest (2006)",
#  'The Ring (2002)': 'Saw (2004)',
#  'The Truman Show (1998)': 'The Sting (1973)',
#  'Forrest Gump (1994)': 'Rain Man (1988)',
#  'I.Q. (1994)': 'The Core (2003)',
#  'Goodfellas (1990)': 'The Sting (1973)',
#  'Uptown Girls (2003)': 'Escape from LA (1996)',
#  'Beauty and the Beauty (1991)': 'Aladdin (1992)',
#  'Black Hawk Down (2001)': 'Erik the Viking (1989)',
#  'Knight and Day (2010)': 'Point Break (1991)',
#  'The Shawshank Redemption (1994)': 'The Insider (1999)',
#  'Sleepy Hollow (1999)': 'L.A. Confidential (1997)',
#  'The Holiday (2006)': 'What Lies Beneath (2000)',
#  'Sixteen Candles (1984)': 'Best Laid Plans (1999)',
#  '10000 BC (2008)': 'The Hulk (2003)',
#  'Austin Powers: The Spy Who Shagged Me (1999)': 'Austin Powers in Goldmember (2002)',
#  'The Lion King (1994)': 'Monsters  Inc.(2001)',
#  "Child's Play (1988)": 'Friday the 13th Part III (1982)',
#  'Anger Management (2002)': 'Hollow Man (2000)',
#  'Angels in the Outfield (1994)': 'Heavy Traffic (1973)',
#  'Wild Wild West (1999)': 'JFK (1991)',
#  'Split (2016)': 'Cloverfield (2008)',
#  'Bad Boys (1995)': 'Bad Boys 2 (2003)',
#  'The Prestige (2006)': 'What Lies Beneath (2000)',
#  'American Graffiti (1973)': 'Escape from LA (1996)',
#  'Air Force One (1997)': 'The Final Conflict (1981)',
#  "Harry Potter and the Sorcerer's Stone (2001)": 'Harry Potter and the Chamber of Secrets (2002)',
#  'Close Encounters of the Third Kind (1977)': 'I.Q. (1994)',
#  'Hollow Man (2000)': 'Crimson Tide (1995)',
#  'Point Break (1991)': 'Knight and Day (2010)',
#  'I Robot (2004)': 'Sexy Beast (2000)',
#  'Batman: The Dark Knight (2008)': 'Crimson Tide (1995)',
#  'Ghost (1990)': 'Crimson Tide (1995)',
#  "A Bug's Life (1998)": 'Monsters  Inc.(2001)',
#  'American Pie (1999)': 'Meet the Parents (2000)',
#  'Daredevil (2003)': 'The Hulk (2003)',
#  'The Bandit (1996)': 'The Hulk (2003)',
#  'Grease (1978)': 'The Straight Story (1999)',
#  'The Girl Next Door (2004)': 'Hollow Man (2000)',
#  'The Godfather (1972)': 'The Godfather: Part II (1974)',
#  'Cloverfield (2008)': 'Blow (2001)',
#  'Rush Hour 2 (2001)': 'The Mummy Returns (2001)',
#  'Bruce Almighty (2003)': 'Men in Black (1997)',
#  'Girl With a Pearl Earring (2003)': 'Halloween (1978)',
#  'Grown Ups 2 (2013)': 'Cheaper by the Dozen (2003)',
#  'Best Laid Plans (1999)': 'The Bandit (1996)',
#  "Bram Stoker's Dracula (1992)": 'Chicago (2002)',
#  'Fahrenheit 9/11 (2004)': 'Erik the Viking (1989)',
#  'Donnie Darko (2001)': 'A Clockwork Orange (1971)',
#  'Bad Teacher (2011)': 'American Pie (1999)',
#  'Cable Guy (1996)': 'Crimson Tide (1995)',
#  'Ice Age (2002)': 'Shrek (2001)',
#  'Misery (1990)': 'What Lies Beneath (2000)',
#  '8 Mile (2002)': 'Rocky (1976)',
#  'Harry Potter and the Deathly Hallows: Part 2 (2011)': "Harry Potter and the Sorcerer's Stone (2001)",
#  'Ouija: Origin of Evil (2016)': 'Scream 3 (2000)',
#  'The Deer Hunter (1978)': 'A Perfect Murder (1998)',
#  "There's Something About Mary (1998)": 'Uptown Girls (2003)',
#  'Zoolander (2001)': 'Austin Powers: The Spy Who Shagged Me (1999)',
#  'The Core (2003)': 'I.Q. (1994)',
#  'Spirited Away (2001)': 'Erik the Viking (1989)',
#  'Rocky (1976)': 'Life is Beautiful (1997)',
#  'Traffic (2000)': 'Requiem for a Dream (2000)',
#  'Monsters  Inc.(2001)': 'Toy Story (1995)',
#  'Thoroughly Modern Millie (1967)': 'The Truman Show (1998)',
#  'Requiem for a Dream (2000)': 'Once Upon a Time in the West (1968)',
#  'Downfall (2004)': 'The Lookout (2007)',
#  'L.A. Confidential (1997)': 'The Deer Hunter (1978)',
#  'Chicago (2002)': 'What Lies Beneath (2000)',
#  'Star Wars: Episode 1 - The Phantom Menace (1999)': 'Star Wars: Episode II - Attack of the Clones (2002)',
#  'Rain Man (1988)': 'The Deer Hunter (1978)',
#  'What Lies Beneath (2000)': 'Chicago (2002)',
#  'Toy Story (1995)': 'Toy Story 2 (1999)',
#  "Boy's Don't Cry (1999)": 'Chicago (2002)',
#  'Pearl Harbor (2001)': 'Wild Wild West (1999)',
#  'A.I. Artificial Intelligence (2001)': 'Chicago (2002)',
#  'The Sting (1973)': 'The Core (2003)',
#  'Scream 3 (2000)': 'Scream (1996)',
#  'Congo (1995)': 'The Straight Story (1999)',
#  'Bowling For Columbine (2002)': 'Chicago (2002)',
#  'What Women Want (2000)': 'Crimson Tide (1995)',
#  'Home Alone (1990)': 'The Lookout (2007)',
#  'How the Grinch Stole Christmas (2000)': 'Erik the Viking (1989)',
#  'The Straight Story (1999)': 'Chicago (2002)',
#  'The Hulk (2003)': 'The Bandit (1996)',
#  'Gigli (2002)': 'What Lies Beneath (2000)',
#  'Rocky V (1991)': 'Rocky (1976)',
#  'The Visit (2015)': 'The Shining (1980)',
#  'Titanic (1997)': 'Cocktail (1988)',
#  'A Clockwork Orange (1971)': 'Donnie Darko (2001)',
#  "Charlie's Angels (2000)": 'Moonraker (1979)',
#  'Friday the 13th Part III (1982)': 'Scream 3 (2000)',
#  'Hannibal (2001)': "Can't Hardly Wait (1998)",
#  'Pulp Fiction (1994)': 'Spirited Away (2001)',
#  'Crimson Tide (1995)': 'Cable Guy (1996)',
#  'Blow (2001)': 'Crimson Tide (1995)',
#  'Ran (1985)': 'Heavy Traffic (1973)',
#  'Mulholland Dr. (2001)': 'Once Upon a Time in the West (1968)',
#  'Apocalypse Now (1979)': 'Pulp Fiction (1994)',
#  'Cinema Paradiso (1988)': 'City of God (2002)',
#  'Double Jeopardy (1999)': 'Analyze That (2002)',
#  'The Big Lebowski (1998)': 'Escape from LA (1996)',
#  'The Matrix (1999)': 'The Matrix Reloaded (2003)',
#  'The Lord of the Rings: The Return of the King (2003)': 'The Lord of the Rings: The Two Towers (2002)',
#  'Reservoir Dogs (1992)': 'The Sting (1973)',
#  'Heavy Traffic (1973)': 'Ran (1985)',
#  'Memento (2000)': 'The Prestige (2006)',
#  'Dogville (2003)': 'Suspiria (1977)',
#  'American Psycho (2000)': 'Apocalypse Now (1979)',
#  'Kill Bill: Vol. 1 (2003)': 'Kill Bill: Vol. 2 (2004)',
#  'The Fugitive (1993)': 'Meet the Parents (2000)',
#  'Bend it Like Beckham (2002)': "My Best Friend's Wedding (1997)",
#  'Austin Powers in Goldmember (2002)': 'Austin Powers: The Spy Who Shagged Me (1999)',
#  'The Mummy Returns (2001)': 'The Mummy (1999)',
#  'The Nightmare Before Christmas (1993)': 'Aladdin (1992)',
#  'La La Land (2016)': 'Titanic (1997)',
#  'Flowers in the Attic (1987)': 'The Life of David Gale (2003)',
#  '28 Days Later (2002)': 'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'The Princess Bride (1987)': 'Cocktail (1988)',
#  'The Green Mile (1999)': 'The Game (1997)',
#  'Predator (1987)': 'L.A. Confidential (1997)',
#  'A Night at the Roxbury (1998)': 'Sexy Beast (2000)',
#  'Ed Wood (1994)': 'The Station Agent (2003)',
#  'Aliens (1986)': 'Alien (1979)',
#  'Meet the Parents (2000)': 'FeardotCom (2002)',
#  'Independence Day (1996)': 'Black Hawk Down (2001)',
#  'Who Framed Roger Rabbit (1988)': 'Escape from LA (1996)',
#  'As Good as it Gets (1997)': 'Analyze That (2002)',
#  'Butch Cassidy and the Sundance Kid (1969)': 'Along Came a Spider (2002)',
#  "You're Next (2011)": 'Halloween (1978)',
#  'The Final Conflict (1981)': 'Air Force One (1997)',
#  'City of God (2002)': 'Suspiria (1977)',
#  'Star Wars: Episode VII - The Force Awakens (2015)': 'Star Wars: Episode VI - The Return of the Jedi (1983)',
#  'The Transporter (2002)': 'Halloween (1978)',
#  'Cast Away (2000)': 'Analyze That (2002)',
#  'Bad Boys 2 (2003)': 'Bad Boys (1995)',
#  'The Babadook (2014)': 'The Deer Hunter (1978)',
#  'Saw (2004)': 'The Ring (2002)',
#  'Star Wars: Episode VI - The Return of the Jedi (1983)': 'Star Wars: Episode V - The Empire Strikes Back (1980)',
#  'Scary Movie (2000)': 'Anaconda (1997)',
#  'E.T. The Extra-Terrestrial (1982)': 'My Father and My Son (2005)',
#  'American History X (1998)': 'Mrs. Doubtfire (1993)',
#  'FeardotCom (2002)': 'Ran (1985)',
#  'Halloween (1978)': 'The Texas Chainsaw Massacre (1974)',
#  'Along Came a Spider (2002)': 'Butch Cassidy and the Sundance Kid (1969)',
#  'The Mist (2007)': 'I Know What You Did Last Summer (1997)',
#  'Aladdin (1992)': 'The Lion King (1994)',
#  'Pirates of the Caribbean: The Curse of the Black Pearl (2003)': "Pirates of the Caribbean: At World's End (2007)",
#  'Men in Black (1997)': 'Men in Black II (2002)',
#  'Eternal Sunshine of the Spotless Mind (2004)': 'The Deer Hunter (1978)',
#  "Ocean's Eleven (2001)": 'Analyze That (2002)',
#  'Men in Black II (2002)': 'Men in Black (1997)',
#  'Cocktail (1988)': 'The Lookout (2007)',
#  'The Wolf of Wall Street (2013)': 'Inception (2010)',
#  'The Game (1997)': "My Best Friend's Wedding (1997)",
#  'Red Sonja (1985)': 'Blazing Saddles (1974)',
#  "One Flew Over the Cuckoo's Nest (1975)": 'The Shawshank Redemption (1994)',
#  'Freddy Got Fingered (2001)': 'Wing Commander (1999)',
#  'The Village (2004)': 'The Lookout (2007)',
#  "Miller's Crossing (1990)": 'Suspiria (1977)',
#  "My Best Friend's Wedding (1997)": 'Runaway Bride (1999)',
#  'Iron Man 3 (2013)': 'The Avengers (2012)',
#  'Big Daddy (1999)': 'Crimson Tide (1995)',
#  'Suspiria (1977)': 'Runaway Bride (1999)',
#  'The Passenger (1975)': 'Girl With a Pearl Earring (2003)',
#  'The Station Agent (2003)': 'Ed Wood (1994)',
#  'Jurassic Park (1993)': 'The Lost World: Jurassic Park (1997)',
#  'Captain America: Civil War (2016)': 'The Avengers (2012)',
#  'A Perfect Murder (1998)': 'The Deer Hunter (1978)',
#  'Analyze That (2002)': 'Double Jeopardy (1999)',
#  'Braveheart (1995)': 'Blow (2001)',
#  'Inception (2010)': 'The Prestige (2006)',
#  'Groundhog Day (1993)': 'FeardotCom (2002)',
#  'The Lookout (2007)': 'Anaconda (1997)',
#  '21 Grams (2003)': 'Freddy Got Fingered (2001)',
#  'Gladiator (2000)': 'Braveheart (1995)',
#  'Midnight Cowboy (1969)': 'Apocalypse Now (1979)',
#  'Fatal Attraction (1987)': 'JFK (1991)',
#  'House of Sand and Fog (2003)': 'Midnight Cowboy (1969)',
#  'On Golden Pond (1981)': "You're Next (2011)",
#  'The Mummy (1999)': 'The Mummy Returns (2001)',
#  'The Descent (2005)': 'Suspiria (1977)',
#  'Runaway Bride (1999)': "My Best Friend's Wedding (1997)",
#  'Harry Potter and the Goblet of Fire (2005)': 'Harry Potter and the Chamber of Secrets (2002)',
#  'Gods and Generals (2003)': 'Midnight Cowboy (1969)',
#  'My Father and My Son (2005)': 'E.T. The Extra-Terrestrial (1982)',
#  'X-Men 2 (2003)': 'X-Men (2000)',
#  'The Usual Suspects (1995)': 'Escape from LA (1996)',
#  'The Mask (1994)': 'Men in Black II (2002)',
#  'Jaws (1975)': 'Jurassic Park (1993)',
#  'Harry Potter and the Chamber of Secrets (2002)': "Harry Potter and the Sorcerer's Stone (2001)",
#  'Patton (1970)': 'The Village (2004)',
#  'Anaconda (1997)': 'Scary Movie (2000)',
#  'Twister (1996)': 'Moonraker (1979)',
#  'MacArthur (1977)': 'Cinema Paradiso (1988)',
#  "Look Who's Talking (1989)": 'Ran (1985)'}

# %% [markdown]
# Then report the average COD of those 400 simple linear regression models

# %%
avg_cod = np.mean(list(movie_cod.values()))
avg_cod
# Out:
# 0.37862277330756244

# %% [markdown]
# Please include a histogram of these 400 COD values

# %%
sns.histplot(movie_cod.values(), legend=False)
plt.title('Histogram of Linear Regression CODs')
plt.xlabel('COD')
plt.ylabel('Count')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Count')

# %% [markdown]
# Table with the 10 movies that are most easily predicted from the ratings of a single other movie, (and their associated COD values, as well as which movie ratings are the best predictor, so this table should have 3 columns).

# %%
best_pred_by_single = sorted(movie_score.items(), key=lambda x:np.abs(x[1]))[:10]

# %%
best_pred_by_single
# Out:
# [('The Lookout (2007)', 24.401465259445196),
#  ('The Final Conflict (1981)', 24.78252136573552),
#  ('FeardotCom (2002)', 25.144002750718002),
#  ('Heavy Traffic (1973)', 25.545054287305884),
#  ('Patton (1970)', 25.816829802900667),
#  ('The Straight Story (1999)', 28.112660772295282),
#  ('Sexy Beast (2000)', 28.656409216426567),
#  ('The Bandit (1996)', 29.520271368923137),
#  ('Erik the Viking (1989)', 30.16554760036705),
#  ('The Station Agent (2003)', 31.05128433175851)]

# %%
pd.DataFrame.from_records([{'Movie':k, 'COD':movie_cod[k], 'Best Predictor Movie':movie_best_predictor[k]} for k,v in best_pred_by_single])
# Out:
#                        Movie       COD     Best Predictor Movie
# 0         The Lookout (2007)  0.639742          Anaconda (1997)
# 1  The Final Conflict (1981)  0.642106     Air Force One (1997)
# 2          FeardotCom (2002)  0.647786               Ran (1985)
# 3       Heavy Traffic (1973)  0.644777               Ran (1985)
# 4              Patton (1970)  0.665855       The Village (2004)
# 5  The Straight Story (1999)  0.661787           Chicago (2002)
# 6          Sexy Beast (2000)  0.634867  Scent of a Woman (1992)
# 7          The Bandit (1996)  0.543114          The Hulk (2003)
# 8     Erik the Viking (1989)  0.639866              I.Q. (1994)
# 9   The Station Agent (2003)  0.609859           Ed Wood (1994)

# %% [markdown]
# Table with the 10 movies that are most difficult to predict from the ratings of a single other movie, (and their associated COD values, as well as which movie ratings are the best predictor, so this table should have 3 columns).

# %%
hardest_pred_by_single = sorted(movie_score.items(), key=lambda x:np.abs(x[1]), reverse=True)[:10]

# %%
hardest_pred_by_single
# Out:
# [('Avatar (2009)', 956.7591638292079),
#  ('Elf (2003)', 723.8977229269298),
#  ('Ice Age (2002)', 632.4875016333946),
#  ('The Conjuring (2013)', 626.1434802433565),
#  ('La La Land (2016)', 622.0712904223886),
#  ('Titanic (1997)', 597.3794718033457),
#  ('How the Grinch Stole Christmas (2000)', 588.9287384314651),
#  ('Cheaper by the Dozen (2003)', 570.7109773974348),
#  ('The Fast and the Furious (2001)', 564.9582806838878),
#  ('Home Alone (1990)', 558.0470049490536)]

# %%
pd.DataFrame.from_records([{'Movie':k, 'COD':movie_cod[k], 'Best Predictor Movie':movie_best_predictor[k]} for k,v in hardest_pred_by_single])
# Out:
#                                    Movie       COD  \
# 0                          Avatar (2009)  0.078955
# 1                             Elf (2003)  0.191819
# 2                         Ice Age (2002)  0.197096
# 3                   The Conjuring (2013)  0.224324
# 4                      La La Land (2016)  0.139589
# 5                         Titanic (1997)  0.150350
# 6  How the Grinch Stole Christmas (2000)  0.221887
# 7            Cheaper by the Dozen (2003)  0.217630
# 8        The Fast and the Furious (2001)  0.169708
# 9                      Home Alone (1990)  0.211512
#
#                                 Best Predictor Movie
# 0  Pirates of the Caribbean: Dead Man's Chest (2006)
# 1                        Cheaper by the Dozen (2003)
# 2                                       Shrek (2001)
# 3                                The Exorcist (1973)
# 4                                     Titanic (1997)
# 5                                    Cocktail (1988)
# 6                             Erik the Viking (1989)
# 7                              Escape from LA (1996)
# 8             Transformers: Age of Extinction (2014)
# 9                                 The Lookout (2007)

# %% [markdown]
# ## AFYD for Question 1
#
# 1. **D**: What did you do - what assumptions/choices did you make, if any (e.g. re
# independence, type of data, etc.)?
#
#     - We chose to only train and evaluate using known targets. That is, not training on filled labels.
#     - We chose to evaluate performance using MSE. By easily predicted, we made the choice to mean: With the lowest Mean Squared Error.
#     - We dropped all users with no known ratings (that is, that haven't rated even a movie). Just one user in this case.
#
# 3. **Y**: Why did you do this - what was the reasoning for doing this (over all other possible things you could have done)?
#
#     - In order to model the intended variable and only evaluate for known data, as due to sparsity, the training data would mostly consist of filled target values otherwise.
#     - This is the same metric that OLS regression minimizes.
#     - Such users are untreatable given the recommendations for the project.
#
# 4. **F**: What did you find doing that - at least one number (e.g. a p-value or an effect size), better a number *and* a figure. Context is better – what does the number represent, how was it arrived at (what was the test statistic and degrees of freedom?)
#
#     - Best single predictor for each movie.
#     - An average COD of 0.378.
#     - The histogram.
#     - The two tables.
#
# 6. **A**: Given all of that, how do you answer the question, sth like "Given that my p value is x, I conclude that y]. If you made any questionable assumptions above, this is also where you might want to state limitations to the scope of your answer, if there are any, and you are aware of them. It's fine to have limitations, if you spell them out (e.g. concerns about alpha inflation, independence, distribution of data, etc - if there are any).
#
#         - TBD

# %% [markdown]
# # Question 2

# %% [markdown]
# For the 10 movies that are best and least well predicted from the ratings of a single other movie (so 20 in total), build multiple regression models that include gender identity (column 475), sibship status (column 476) and social viewing preferences (column 477) as additional predictors (in addition to the best predicting movie from question 1). Comment on how R^2 has changed relative to the answers in question 1. Please include a figure with a scatterplot where the old COD (for the simple linear regression models from the previous question) is on the x-axis and the new R^2 (for the new multiple regression models) is on the y-axis.

# %%
selected_movies = [x[0] for x in best_pred_by_single + hardest_pred_by_single]

# %%
selected_movies
# Out:
# ['The Lookout (2007)',
#  'The Final Conflict (1981)',
#  'FeardotCom (2002)',
#  'Heavy Traffic (1973)',
#  'Patton (1970)',
#  'The Straight Story (1999)',
#  'Sexy Beast (2000)',
#  'The Bandit (1996)',
#  'Erik the Viking (1989)',
#  'The Station Agent (2003)',
#  'Avatar (2009)',
#  'Elf (2003)',
#  'Ice Age (2002)',
#  'The Conjuring (2013)',
#  'La La Land (2016)',
#  'Titanic (1997)',
#  'How the Grinch Stole Christmas (2000)',
#  'Cheaper by the Dozen (2003)',
#  'The Fast and the Furious (2001)',
#  'Home Alone (1990)']

# %%
gender_vals = df.loc[df_movies.index][gender_identity_cols[0]].values
sibship_vals = df.loc[df_movies.index][only_child_cols[0]].values
social_vals = df.loc[df_movies.index][alone_cols[0]].values

# %%
movie_cod_q2 = dict()

for movie in selected_movies:
    predictor_movie = movie_best_predictor[movie]
    y = df_movies[movie].values.reshape(-1)
    valid_mask = ~np.isnan(y)
    y = y[valid_mask]
    m = df_filled[predictor_movie].values[valid_mask]
    g = gender_vals[valid_mask]
    g[np.isnan(g)] = np.nanmean(g)
    si = sibship_vals[valid_mask]
    si[np.isnan(si)] = np.nanmean(si)
    so = social_vals[valid_mask]
    so[np.isnan(so)] = np.nanmean(so)
    X = np.transpose(np.vstack([m,g,si,so]))
    reg = LinearRegression().fit(X, y)
    movie_cod_q2[movie] = reg.score(X, y)

# %%
movie_cod_q2
# Out:
# {'The Lookout (2007)': 0.6429635724535165,
#  'The Final Conflict (1981)': 0.6444125132424803,
#  'FeardotCom (2002)': 0.6552751741995342,
#  'Heavy Traffic (1973)': 0.6550439761448436,
#  'Patton (1970)': 0.6882585480325183,
#  'The Straight Story (1999)': 0.6731465527073617,
#  'Sexy Beast (2000)': 0.6670369860966227,
#  'The Bandit (1996)': 0.5811590272646856,
#  'Erik the Viking (1989)': 0.6615390004166636,
#  'The Station Agent (2003)': 0.6336683423675337,
#  'Avatar (2009)': 0.08572231980168588,
#  'Elf (2003)': 0.20064067726143453,
#  'Ice Age (2002)': 0.19738922582846263,
#  'The Conjuring (2013)': 0.23128392258566566,
#  'La La Land (2016)': 0.14697765350477887,
#  'Titanic (1997)': 0.1553365716235342,
#  'How the Grinch Stole Christmas (2000)': 0.2267383261224425,
#  'Cheaper by the Dozen (2003)': 0.23688700946880803,
#  'The Fast and the Furious (2001)': 0.1720386901964489,
#  'Home Alone (1990)': 0.21325196841245297}

# %%
movie_cod_q1 = {x:movie_cod[x] for x in selected_movies}
movie_cod_q1
# Out:
# {'The Lookout (2007)': 0.6397421467601594,
#  'The Final Conflict (1981)': 0.6421061638137184,
#  'FeardotCom (2002)': 0.6477858410255248,
#  'Heavy Traffic (1973)': 0.6447768634587197,
#  'Patton (1970)': 0.6658547383880882,
#  'The Straight Story (1999)': 0.6617871653351278,
#  'Sexy Beast (2000)': 0.6348671408145876,
#  'The Bandit (1996)': 0.5431143031374798,
#  'Erik the Viking (1989)': 0.6398663743854509,
#  'The Station Agent (2003)': 0.6098587097457582,
#  'Avatar (2009)': 0.0789554054106042,
#  'Elf (2003)': 0.19181924243660242,
#  'Ice Age (2002)': 0.19709586831969617,
#  'The Conjuring (2013)': 0.22432422490590254,
#  'La La Land (2016)': 0.1395885778060808,
#  'Titanic (1997)': 0.15035028667690042,
#  'How the Grinch Stole Christmas (2000)': 0.2218869003009729,
#  'Cheaper by the Dozen (2003)': 0.21762960340271387,
#  'The Fast and the Furious (2001)': 0.16970839101153168,
#  'Home Alone (1990)': 0.2115121225428681}

# %%
df_q1 = pd.DataFrame(list(movie_cod_q1.items()), columns=['Movie', 'COD'])
df_q2 = pd.DataFrame(list(movie_cod_q2.items()), columns=['Movie', 'COD'])

# Add a 'Source' column to identify the source of data
df_q1['Regression Type'] = 'Only Movie Predictor'
df_q2['Regression Type'] = 'Movie + Other Predictors'

# Concatenate the DataFrames vertically
combined_df = pd.concat([df_q1, df_q2])

# Create the Seaborn plot
sns.set(style="whitegrid")  # Optional: Set the style
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
plot = sns.scatterplot(x="Movie", y="COD", hue="Regression Type", data=combined_df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')

# Customize the plot
plt.title("Comparison of Regressions from Q1 and Q2")
plt.xlabel("Movie")
plt.ylabel("COD")
plt.legend(title="Regression Type", loc="upper right")

# Show the plot
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/homebrew/Caskroom/miniforge/base/envs/python_3_11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /var/folders/jt/k9b7wwrn7fnc6l3g0xlf5xn80000gn/T/ipykernel_94766/2460814824.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')

# %% [markdown]
# ## AFYD for Question 2
#
# 1. **D**: What did you do - what assumptions/choices did you make, if any (e.g. re
# independence, type of data, etc.)?
#
#     - We chose to only train and evaluate using known targets. That is, not training on filled labels.
#     - We chose to fill unknown answers to gender identity (column 475), sibship status (column 476) and social viewing preferences (column 477) with the mean, for the users who had rated each movie.
#
# 3. **Y**: Why did you do this - what was the reasoning for doing this (over all other possible things you could have done)?
#
#     - In order to model the intended variable and only evaluate for known data, as due to sparsity, the training data would mostly consist of filled target values otherwise.
#     - Some users would need to be dropped otherwise. Each non-rating question has a different meaning, and each answer is treated as a continuous variable because we are using OLS. Therefore, the mean should at least allow us to observe the other known variables in the training data for those paired samples.
#
# 4. **F**: What did you find doing that - at least one number (e.g. a p-value or an effect size), better a number *and* a figure. Context is better – what does the number represent, how was it arrived at (what was the test statistic and degrees of freedom?)
#
#     - Modest COD improvement at best, see plot.
#
# 6. **A**: Given all of that, how do you answer the question, sth like "Given that my p value is x, I conclude that y]. If you made any questionable assumptions above, this is also where you might want to state limitations to the scope of your answer, if there are any, and you are aware of them. It's fine to have limitations, if you spell them out (e.g. concerns about alpha inflation, independence, distribution of data, etc - if there are any).
#
#         - TBD
